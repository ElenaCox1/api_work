# %%
import requests
response = requests.get(f'https://api.darksky.net/forecast/{api_key}/40,-78')
weather = response.json()
print(response.text)
# Out:
# {"latitude":40,"longitude":-78,"timezone":"America/New_York","currently":{"time":1559839148,"summary":"Overcast","icon":"cloudy","nearestStormDistance":27,"nearestStormBearing":6,"precipIntensity":0,"precipProbability":0,"temperature":80.04,"apparentTemperature":81.53,"dewPoint":63.38,"humidity":0.57,"pressure":1010.32,"windSpeed":6.62,"windGust":7.43,"windBearing":302,"cloudCover":1,"uvIndex":3,"visibility":10,"ozone":326.7},"minutely":{"summary":"Overcast for the hour.","icon":"cloudy","data":[{"time":1559839140,"precipIntensity":0,"precipProbability":0},{"time":1559839200,"precipIntensity":0,"precipProbability":0},{"time":1559839260,"precipIntensity":0,"precipProbability":0},{"time":1559839320,"precipIntensity":0,"precipProbability":0},{"time":1559839380,"precipIntensity":0,"precipProbability":0},{"time":1559839440,"precipIntensity":0,"precipProbability":0},{"time":1559839500,"precipIntensity":0,"precipProbability":0},{"time":1559839560,"precipIntensity":0,"precipProbability":0},{
# ...

# %%
weather
# Out:
# {'latitude': 40,
#  'longitude': -78,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1559839148,
#   'summary': 'Overcast',
#   'icon': 'cloudy',
#   'nearestStormDistance': 27,
#   'nearestStormBearing': 6,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 80.04,
#   'apparentTemperature': 81.53,
#   'dewPoint': 63.38,
#   'humidity': 0.57,
#   'pressure': 1010.32,
#   'windSpeed': 6.62,
#   'windGust': 7.43,
#   'windBearing': 302,
#   'cloudCover': 1,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 326.7},
#  'minutely': {'summary': 'Overcast for the hour.',
#   'icon': 'cloudy',
#   'data': [{'time': 1559839140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559839200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559839260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559839320, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %%
weather['currently']['temperature']
# Out:
# 79.33

# %%
response = requests.get(f'https://api.darksky.net/forecast/{api_key}/10,-102')
weather2 = response.json()
weather2['currently']['temperature']
# Out:
# 84.75

# %%
# !touch .env

# %%
# Out:
# ...
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from dotenv import load_dotenv
load_dotenv()
import os

SECRET_KEY = os.getenv("DARKSKY_API_KEY")
